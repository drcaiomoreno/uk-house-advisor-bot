# %%
# %sh
rm /Volumes/caio_moreno/uk_house_advisor_bot/files/pp-2025.csv

# %%
# %sh
rm /Volumes/caio_moreno/uk_house_advisor_bot/files/pp-complete.csv

# %%
# %sh
rm pp-2025.csv

# %%
spark.sql("DROP TABLE IF EXISTS caio_moreno.uk_house_advisor_bot.silver_pp_2025")

# %%
spark.sql("DROP TABLE IF EXISTS caio_moreno.uk_house_advisor_bot.raw_pp_complete")

# %%
spark.sql("DROP TABLE IF EXISTS caio_moreno.uk_house_advisor_bot.raw_pp_2025")
