# %%
# Create Unity Catalog
spark.sql("CREATE CATALOG IF NOT EXISTS caio_moreno")

# Create Unity Catalog Schema
spark.sql("CREATE SCHEMA IF NOT EXISTS caio_moreno.uk_house_advisor_bot")

# %%
# Create Unity Catalog Volume
spark.sql("CREATE VOLUME IF NOT EXISTS caio_moreno.uk_house_advisor_bot.files")

# %%
volumes_df = spark.sql("SHOW VOLUMES IN caio_moreno.uk_house_advisor_bot")
display(volumes_df)

# %%
ls -lh /Volumes/caio_moreno/uk_house_advisor_bot/files
